# %%
import os
import pandas as pd

FILE_PATH = os.path.join("datasets", "ashrae-energy-prediction")

def load_csv_data(csvName, path=FILE_PATH):
    csv_path = os.path.join(path, csvName)
    return pd.read_csv(csv_path)

# %%
building_metadata = load_csv_data("building_metadata.csv")

# %%
building_metadata.head()
# Out:
#    site_id  building_id primary_use  square_feet  year_built  floor_count
# 0        0            0   Education         7432      2008.0          NaN
# 1        0            1   Education         2720      2004.0          NaN
# 2        0            2   Education         5376      1991.0          NaN
# 3        0            3   Education        23685      2002.0          NaN
# 4        0            4   Education       116607      1975.0          NaN

# %%
building_metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1449 entries, 0 to 1448
# Data columns (total 6 columns):
# site_id        1449 non-null int64
# building_id    1449 non-null int64
# primary_use    1449 non-null object
# square_feet    1449 non-null int64
# year_built     675 non-null float64
# floor_count    355 non-null float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 68.0+ KB

# %%
building_metadata.describe()
# Out:
#            site_id  building_id    square_feet   year_built  floor_count
# count  1449.000000  1449.000000    1449.000000   675.000000   355.000000
# mean      6.952381   724.000000   92111.776398  1967.957037     3.740845
# std       5.003432   418.434583  110769.950997    31.054030     3.333683
# min       0.000000     0.000000     283.000000  1900.000000     1.000000
# 25%       3.000000   362.000000   23012.000000  1949.000000     1.000000
# 50%       5.000000   724.000000   57673.000000  1970.000000     3.000000
# 75%      13.000000  1086.000000  115676.000000  1995.000000     5.000000
# max      15.000000  1448.000000  875000.000000  2017.000000    26.000000

# %%
test = load_csv_data("test.csv")

# %%
test.head()
# Out:
#    row_id  building_id  meter            timestamp
# 0       0            0      0  2017-01-01 00:00:00
# 1       1            1      0  2017-01-01 00:00:00
# 2       2            2      0  2017-01-01 00:00:00
# 3       3            3      0  2017-01-01 00:00:00
# 4       4            4      0  2017-01-01 00:00:00

# %%
train = load_csv_data("train.csv")

# %%
train.head()
# Out:
#    building_id  meter            timestamp  meter_reading
# 0            0      0  2016-01-01 00:00:00            0.0
# 1            1      0  2016-01-01 00:00:00            0.0
# 2            2      0  2016-01-01 00:00:00            0.0
# 3            3      0  2016-01-01 00:00:00            0.0
# 4            4      0  2016-01-01 00:00:00            0.0

# %%
train.describe()
# Out:
#         building_id         meter  meter_reading
# count  2.021610e+07  2.021610e+07   2.021610e+07
# mean   7.992780e+02  6.624412e-01   2.117121e+03
# std    4.269133e+02  9.309921e-01   1.532356e+05
# min    0.000000e+00  0.000000e+00   0.000000e+00
# 25%    3.930000e+02  0.000000e+00   1.830000e+01
# 50%    8.950000e+02  0.000000e+00   7.877500e+01
# 75%    1.179000e+03  1.000000e+00   2.679840e+02
# max    1.448000e+03  3.000000e+00   2.190470e+07

# %%
weather_train = load_csv_data("weather_train.csv")

# %%
weather_train.head()
# Out:
#    site_id            timestamp  air_temperature  cloud_coverage  \
# 0        0  2016-01-01 00:00:00             25.0             6.0
# 1        0  2016-01-01 01:00:00             24.4             NaN
# 2        0  2016-01-01 02:00:00             22.8             2.0
# 3        0  2016-01-01 03:00:00             21.1             2.0
# 4        0  2016-01-01 04:00:00             20.0             2.0
#
#    dew_temperature  precip_depth_1_hr  sea_level_pressure  wind_direction  \
# 0             20.0                NaN              1019.7             0.0
# 1             21.1               -1.0              1020.2            70.0
# 2             21.1                0.0              1020.2             0.0
# 3             20.6                0.0              1020.1             0.0
# 4             20.0               -1.0              1020.0           250.0
#
#    wind_speed
# 0         0.0
# 1         1.5
# 2         0.0
# 3         0.0
# 4         2.6

# %%
weather_train.describe()
# Out:
#              site_id  air_temperature  cloud_coverage  dew_temperature  \
# count  139773.000000    139718.000000    70600.000000    139660.000000
# mean        7.478977        14.418106        2.149306         7.350158
# std         4.604744        10.626595        2.599150         9.790235
# min         0.000000       -28.900000        0.000000       -35.000000
# 25%         3.000000         7.200000        0.000000         0.600000
# 50%         7.000000        15.000000        2.000000         8.300000
# 75%        11.000000        22.200000        4.000000        14.400000
# max        15.000000        47.200000        9.000000        26.100000
#
#        precip_depth_1_hr  sea_level_pressure  wind_direction     wind_speed
# count       89484.000000       129155.000000   133505.000000  139469.000000
# mean            0.983047         1016.158038      180.526632       3.560527
# std             8.463678            7.629684      111.523629       2.335874
# ...

# %%
train["building_id"]
# Out:
# 0              0
# 1              1
# 2              2
# 3              3
# 4              4
#             ...
# 20216095    1444
# 20216096    1445
# 20216097    1446
# 20216098    1447
# 20216099    1448
# Name: building_id, Length: 20216100, dtype: int64

# %%
import pandas as pd
train_and_building_metadata = pd.merge(train, building_metadata,
                       how="left", on = "building_id")

# %%
train_and_building_metadata.head()
# Out:
#    building_id  meter            timestamp  meter_reading  site_id  \
# 0            0      0  2016-01-01 00:00:00            0.0        0
# 1            1      0  2016-01-01 00:00:00            0.0        0
# 2            2      0  2016-01-01 00:00:00            0.0        0
# 3            3      0  2016-01-01 00:00:00            0.0        0
# 4            4      0  2016-01-01 00:00:00            0.0        0
#
#   primary_use  square_feet  year_built  floor_count
# 0   Education         7432      2008.0          NaN
# 1   Education         2720      2004.0          NaN
# 2   Education         5376      1991.0          NaN
# 3   Education        23685      2002.0          NaN
# 4   Education       116607      1975.0          NaN

# %%
building_id_site_id_meter_reading_weather = pd.merge(train_and_building_metadata.iloc[:,[0,1,2,3,4]], 
                                                     weather_train, 
                                                     how="left", on=["site_id", "timestamp"])

# %%
building_id_site_id_meter_reading_weather
# Out:
#           building_id  meter            timestamp  meter_reading  site_id  \
# 0                   0      0  2016-01-01 00:00:00          0.000        0
# 1                   1      0  2016-01-01 00:00:00          0.000        0
# 2                   2      0  2016-01-01 00:00:00          0.000        0
# 3                   3      0  2016-01-01 00:00:00          0.000        0
# 4                   4      0  2016-01-01 00:00:00          0.000        0
# ...               ...    ...                  ...            ...      ...
# 20216095         1444      0  2016-12-31 23:00:00          8.750       15
# 20216096         1445      0  2016-12-31 23:00:00          4.825       15
# 20216097         1446      0  2016-12-31 23:00:00          0.000       15
# 20216098         1447      0  2016-12-31 23:00:00        159.575       15
# 20216099         1448      0  2016-12-31 23:00:00          2.850       15
#
#           air_temperature  cloud_coverage  dew_temperature  precip_depth_1_hr  \
# ...

# %%
train_and_building_metadata.iloc[:,[0,1,3,4]]
# Out:
#           building_id  meter  meter_reading  site_id
# 0                   0      0          0.000        0
# 1                   1      0          0.000        0
# 2                   2      0          0.000        0
# 3                   3      0          0.000        0
# 4                   4      0          0.000        0
# ...               ...    ...            ...      ...
# 20216095         1444      0          8.750       15
# 20216096         1445      0          4.825       15
# 20216097         1446      0          0.000       15
# 20216098         1447      0        159.575       15
# 20216099         1448      0          2.850       15
#
# [20216100 rows x 4 columns]

# %%
weather_train
# Out:
#         site_id            timestamp  air_temperature  cloud_coverage  \
# 0             0  2016-01-01 00:00:00             25.0             6.0
# 1             0  2016-01-01 01:00:00             24.4             NaN
# 2             0  2016-01-01 02:00:00             22.8             2.0
# 3             0  2016-01-01 03:00:00             21.1             2.0
# 4             0  2016-01-01 04:00:00             20.0             2.0
# ...         ...                  ...              ...             ...
# 139768       15  2016-12-31 19:00:00              3.0             NaN
# 139769       15  2016-12-31 20:00:00              2.8             2.0
# 139770       15  2016-12-31 21:00:00              2.8             NaN
# 139771       15  2016-12-31 22:00:00              2.2             NaN
# 139772       15  2016-12-31 23:00:00              1.7             NaN
#
#         dew_temperature  precip_depth_1_hr  sea_level_pressure  \
# ...

# %%
train_and_building_metadata.iloc[:,[0,1,3,4]]
# Out:
#           building_id  meter  meter_reading  site_id
# 0                   0      0          0.000        0
# 1                   1      0          0.000        0
# 2                   2      0          0.000        0
# 3                   3      0          0.000        0
# 4                   4      0          0.000        0
# ...               ...    ...            ...      ...
# 20216095         1444      0          8.750       15
# 20216096         1445      0          4.825       15
# 20216097         1446      0          0.000       15
# 20216098         1447      0        159.575       15
# 20216099         1448      0          2.850       15
#
# [20216100 rows x 4 columns]

# %%
train_and_building_metadata.describe()
# Out:
#         building_id         meter  meter_reading       site_id   square_feet  \
# count  2.021610e+07  2.021610e+07   2.021610e+07  2.021610e+07  2.021610e+07
# mean   7.992780e+02  6.624412e-01   2.117121e+03  7.992232e+00  1.077830e+05
# std    4.269133e+02  9.309921e-01   1.532356e+05  5.099060e+00  1.171424e+05
# min    0.000000e+00  0.000000e+00   0.000000e+00  0.000000e+00  2.830000e+02
# 25%    3.930000e+02  0.000000e+00   1.830000e+01  3.000000e+00  3.252700e+04
# 50%    8.950000e+02  0.000000e+00   7.877500e+01  9.000000e+00  7.270900e+04
# 75%    1.179000e+03  1.000000e+00   2.679840e+02  1.300000e+01  1.391130e+05
# max    1.448000e+03  3.000000e+00   2.190470e+07  1.500000e+01  8.750000e+05
#
#          year_built   floor_count
# count  8.088455e+06  3.506933e+06
# mean   1.968277e+03  4.184848e+00
# std    3.020815e+01  4.008277e+00
# min    1.900000e+03  1.000000e+00
# 25%    1.951000e+03  1.000000e+00
# 50%    1.969000e+03  3.000000e+00
# ...

# %%
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x115c33410>,
# ...
#       dtype=object)
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x115839ef0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/Documents/repo/ml/env/lib/python3.7/site-packages/matplotlib/pyplot.py in post_execute()
#     107             def post_execute():
#     108                 if matplotlib.is_interactive():
# --> 109                     draw_all()
#     110
#     111             # IPython >= 2
#
# ~/Documents/repo/ml/env/lib/python3.7/site-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     126         for f_mgr in cls.get_all_fig_managers():
#     127             if force or f_mgr.canvas.figure.stale:
# --> 128                 f_mgr.canvas.draw_idle()
#     129
#     130 atexit.register(Gcf.destroy_all)
#
# ...

# %%
train_and_building_metadata_corr = train_and_building_metadata.corr()
train_and_building_metadata_corr["meter_reading"].sort_values(ascending=False)
# Out:
# meter_reading    1.000000
# floor_count      0.130224
# year_built       0.111837
# square_feet      0.024308
# meter            0.017672
# site_id          0.011897
# building_id      0.008761
# Name: meter_reading, dtype: float64

# %%
building_id_site_id_meter_reading_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20216100 entries, 0 to 20216099
# Data columns (total 12 columns):
# building_id           int64
# meter                 int64
# timestamp             object
# meter_reading         float64
# site_id               int64
# air_temperature       float64
# cloud_coverage        float64
# dew_temperature       float64
# precip_depth_1_hr     float64
# sea_level_pressure    float64
# wind_direction        float64
# wind_speed            float64
# dtypes: float64(8), int64(3), object(1)
# memory usage: 2.0+ GB

# %%
building_id_site_id_meter_reading_weather.describe()
# Out:
#         building_id         meter  meter_reading       site_id  \
# count  2.021610e+07  2.021610e+07   2.021610e+07  2.021610e+07
# mean   7.992780e+02  6.624412e-01   2.117121e+03  7.992232e+00
# std    4.269133e+02  9.309921e-01   1.532356e+05  5.099060e+00
# min    0.000000e+00  0.000000e+00   0.000000e+00  0.000000e+00
# 25%    3.930000e+02  0.000000e+00   1.830000e+01  3.000000e+00
# 50%    8.950000e+02  0.000000e+00   7.877500e+01  9.000000e+00
# 75%    1.179000e+03  1.000000e+00   2.679840e+02  1.300000e+01
# max    1.448000e+03  3.000000e+00   2.190470e+07  1.500000e+01
#
#        air_temperature  cloud_coverage  dew_temperature  precip_depth_1_hr  \
# count     2.011944e+07    1.139074e+07     2.011596e+07       1.646708e+07
# mean      1.598795e+01    1.900423e+00     7.747429e+00       7.964155e-01
# std       1.094729e+01    2.402909e+00     1.017867e+01       7.468997e+00
# min      -2.890000e+01    0.000000e+00    -3.500000e+01      -1.000000e+00
# ...

# %%
building_id_site_id_meter_reading_weather_for_corr = building_id_site_id_meter_reading_weather.drop(["site_id", "building_id", "meter"], axis=1)

corr = building_id_site_id_meter_reading_weather_for_corr.corr()
corr["meter_reading"].sort_values(ascending=False)
# Out:
# meter_reading         1.000000
# wind_speed            0.006071
# cloud_coverage        0.006024
# precip_depth_1_hr     0.000509
# wind_direction       -0.000078
# week                 -0.000737
# dew_temperature      -0.003330
# air_temperature      -0.004132
# sea_level_pressure   -0.004220
# Name: meter_reading, dtype: float64

# %%
building_id_site_id_meter_reading_weather
# Out:
#           building_id  meter            timestamp  meter_reading  site_id  \
# 0                   0      0  2016-01-01 00:00:00          0.000        0
# 1                   1      0  2016-01-01 00:00:00          0.000        0
# 2                   2      0  2016-01-01 00:00:00          0.000        0
# 3                   3      0  2016-01-01 00:00:00          0.000        0
# 4                   4      0  2016-01-01 00:00:00          0.000        0
# ...               ...    ...                  ...            ...      ...
# 20216095         1444      0  2016-12-31 23:00:00          8.750       15
# 20216096         1445      0  2016-12-31 23:00:00          4.825       15
# 20216097         1446      0  2016-12-31 23:00:00          0.000       15
# 20216098         1447      0  2016-12-31 23:00:00        159.575       15
# 20216099         1448      0  2016-12-31 23:00:00          2.850       15
#
#           air_temperature  cloud_coverage  dew_temperature  precip_depth_1_hr  \
# ...

# %%
import datetime

timestamp = building_id_site_id_meter_reading_weather["timestamp"]

week = list()

for t in timestamp:
    d = datetime.datetime.strptime(t, '%Y-%m-%d %H:%M:%S')
    week.append(d.weekday())
    
#     print(d.weekday())
#     i += 1
#     if i > 10:
#         break

# %%
week[-1]
# Out:
# 5

# %%
building_id_site_id_meter_reading_weather["week"] = week

# %%
building_id_site_id_meter_reading_weather
# Out:
#           building_id  meter            timestamp  meter_reading  site_id  \
# 0                   0      0  2016-01-01 00:00:00          0.000        0
# 1                   1      0  2016-01-01 00:00:00          0.000        0
# 2                   2      0  2016-01-01 00:00:00          0.000        0
# 3                   3      0  2016-01-01 00:00:00          0.000        0
# 4                   4      0  2016-01-01 00:00:00          0.000        0
# ...               ...    ...                  ...            ...      ...
# 20216095         1444      0  2016-12-31 23:00:00          8.750       15
# 20216096         1445      0  2016-12-31 23:00:00          4.825       15
# 20216097         1446      0  2016-12-31 23:00:00          0.000       15
# 20216098         1447      0  2016-12-31 23:00:00        159.575       15
# 20216099         1448      0  2016-12-31 23:00:00          2.850       15
#
#           air_temperature  cloud_coverage  dew_temperature  precip_depth_1_hr  \
# ...

# %%
corr = building_id_site_id_meter_reading_weather_for_corr.corr()
corr["meter_reading"].sort_values(ascending=False)

# %%
month = building_id_site_id_meter_reading_weather["timestamp"].str.replace('(.*)-(.*)-(.*) (.*)', r'\2', regex=True)
month = month.replace('^0(.*)', r'\1', regex=True)

# %%
building_id_site_id_meter_reading_weather["month"] = month

# %%
building_id_site_id_meter_reading_weather
# Out:
#           building_id  meter            timestamp  meter_reading  site_id  \
# 0                   0      0  2016-01-01 00:00:00          0.000        0
# 1                   1      0  2016-01-01 00:00:00          0.000        0
# 2                   2      0  2016-01-01 00:00:00          0.000        0
# 3                   3      0  2016-01-01 00:00:00          0.000        0
# 4                   4      0  2016-01-01 00:00:00          0.000        0
# ...               ...    ...                  ...            ...      ...
# 20216095         1444      0  2016-12-31 23:00:00          8.750       15
# 20216096         1445      0  2016-12-31 23:00:00          4.825       15
# 20216097         1446      0  2016-12-31 23:00:00          0.000       15
# 20216098         1447      0  2016-12-31 23:00:00        159.575       15
# 20216099         1448      0  2016-12-31 23:00:00          2.850       15
#
#           air_temperature  cloud_coverage  dew_temperature  precip_depth_1_hr  \
# ...

# %%
building_id_site_id_meter_reading_weather = building_id_site_id_meter_reading_weather.drop("month", axis=1)

# %%
building_id_site_id_meter_reading_weather
corr = building_id_site_id_meter_reading_weather.corr()
corr["meter_reading"].sort_values(ascending=False)
# Out:
# meter_reading         1.000000
# meter                 0.017672
# site_id               0.011897
# building_id           0.008761
# wind_speed            0.006071
# cloud_coverage        0.006024
# precip_depth_1_hr     0.000509
# wind_direction       -0.000078
# week                 -0.000737
# dew_temperature      -0.003330
# air_temperature      -0.004132
# sea_level_pressure   -0.004220
# Name: meter_reading, dtype: float64

# %%
building_id_site_id_meter_reading_weather.describe()
# Out:
#         building_id         meter  meter_reading       site_id  \
# count  2.021610e+07  2.021610e+07   2.021610e+07  2.021610e+07
# mean   7.992780e+02  6.624412e-01   2.117121e+03  7.992232e+00
# std    4.269133e+02  9.309921e-01   1.532356e+05  5.099060e+00
# min    0.000000e+00  0.000000e+00   0.000000e+00  0.000000e+00
# 25%    3.930000e+02  0.000000e+00   1.830000e+01  3.000000e+00
# 50%    8.950000e+02  0.000000e+00   7.877500e+01  9.000000e+00
# 75%    1.179000e+03  1.000000e+00   2.679840e+02  1.300000e+01
# max    1.448000e+03  3.000000e+00   2.190470e+07  1.500000e+01
#
#        air_temperature  cloud_coverage  dew_temperature  precip_depth_1_hr  \
# count     2.011944e+07    1.139074e+07     2.011596e+07       1.646708e+07
# mean      1.598795e+01    1.900423e+00     7.747429e+00       7.964155e-01
# std       1.094729e+01    2.402909e+00     1.017867e+01       7.468997e+00
# min      -2.890000e+01    0.000000e+00    -3.500000e+01      -1.000000e+00
# ...

# %%
building_id_site_id_meter_reading_weather_for_corr = building_id_site_id_meter_reading_weather.drop(["precip_depth_1_hr", "wind_direction", "site_id", "building_id", "meter"], axis=1)
corr = building_id_site_id_meter_reading_weather_for_corr.corr()
corr["meter_reading"].sort_values(ascending=False)
# Out:
# meter_reading         1.000000
# wind_speed            0.006071
# cloud_coverage        0.006024
# week                 -0.000737
# dew_temperature      -0.003330
# air_temperature      -0.004132
# sea_level_pressure   -0.004220
# Name: meter_reading, dtype: float64

# %%
building_id_site_id_meter_reading_weather_for_corr
# Out:
#                     timestamp  meter_reading  air_temperature  cloud_coverage  \
# 0         2016-01-01 00:00:00          0.000             25.0             6.0
# 1         2016-01-01 00:00:00          0.000             25.0             6.0
# 2         2016-01-01 00:00:00          0.000             25.0             6.0
# 3         2016-01-01 00:00:00          0.000             25.0             6.0
# 4         2016-01-01 00:00:00          0.000             25.0             6.0
# ...                       ...            ...              ...             ...
# 20216095  2016-12-31 23:00:00          8.750              1.7             NaN
# 20216096  2016-12-31 23:00:00          4.825              1.7             NaN
# 20216097  2016-12-31 23:00:00          0.000              1.7             NaN
# 20216098  2016-12-31 23:00:00        159.575              1.7             NaN
# 20216099  2016-12-31 23:00:00          2.850              1.7             NaN
#
# ...

# %%
building_id_site_id_meter_reading_weather
# Out:
#           building_id  meter            timestamp  meter_reading  site_id  \
# 0                   0      0  2016-01-01 00:00:00          0.000        0
# 1                   1      0  2016-01-01 00:00:00          0.000        0
# 2                   2      0  2016-01-01 00:00:00          0.000        0
# 3                   3      0  2016-01-01 00:00:00          0.000        0
# 4                   4      0  2016-01-01 00:00:00          0.000        0
# ...               ...    ...                  ...            ...      ...
# 20216095         1444      0  2016-12-31 23:00:00          8.750       15
# 20216096         1445      0  2016-12-31 23:00:00          4.825       15
# 20216097         1446      0  2016-12-31 23:00:00          0.000       15
# 20216098         1447      0  2016-12-31 23:00:00        159.575       15
# 20216099         1448      0  2016-12-31 23:00:00          2.850       15
#
#           air_temperature  cloud_coverage  dew_temperature  precip_depth_1_hr  \
# ...

# %%
corr = building_id_site_id_meter_reading_weather.corr()

# %%
corr["meter_reading"].sort_values(ascending=False)
# Out:
# meter_reading         1.000000
# meter                 0.017672
# site_id               0.011897
# building_id           0.008761
# wind_speed            0.006071
# cloud_coverage        0.006024
# precip_depth_1_hr     0.000509
# wind_direction       -0.000078
# week                 -0.000737
# dew_temperature      -0.003330
# air_temperature      -0.004132
# sea_level_pressure   -0.004220
# Name: meter_reading, dtype: float64

# %%
building_id_site_id_meter_reading_weather
# Out:
#           building_id  meter            timestamp  meter_reading  site_id  \
# 0                   0      0  2016-01-01 00:00:00          0.000        0
# 1                   1      0  2016-01-01 00:00:00          0.000        0
# 2                   2      0  2016-01-01 00:00:00          0.000        0
# 3                   3      0  2016-01-01 00:00:00          0.000        0
# 4                   4      0  2016-01-01 00:00:00          0.000        0
# ...               ...    ...                  ...            ...      ...
# 20216095         1444      0  2016-12-31 23:00:00          8.750       15
# 20216096         1445      0  2016-12-31 23:00:00          4.825       15
# 20216097         1446      0  2016-12-31 23:00:00          0.000       15
# 20216098         1447      0  2016-12-31 23:00:00        159.575       15
# 20216099         1448      0  2016-12-31 23:00:00          2.850       15
#
#           air_temperature  cloud_coverage  dew_temperature  precip_depth_1_hr  \
# ...

# %%
month_day = building_id_site_id_meter_reading_weather["timestamp"].str.replace('(.*)-(.*)-(.*) (.*)', r'\2\1', regex=True)
month_day_enc = month_day.replace('^0(.*)', r'\1', regex=True)

# %%
month_day_enc_int = month_day_enc.astype(int)

# %%
building_id_site_id_meter_reading_weather["month"] = month_day_enc_int

# %%
corr2 = building_id_site_id_meter_reading_weather.corr()
corr2["meter_reading"].sort_values(ascending=False)
# Out:
# meter_reading         1.000000
# meter                 0.017672
# site_id               0.011897
# building_id           0.008761
# wind_speed            0.006071
# cloud_coverage        0.006024
# precip_depth_1_hr     0.000509
# wind_direction       -0.000078
# week                 -0.000737
# dew_temperature      -0.003330
# air_temperature      -0.004132
# sea_level_pressure   -0.004220
# month                -0.006681
# Name: meter_reading, dtype: float64

# %%
# Out:
# meter_reading         1.000000
# meter                 0.017672
# site_id               0.011897
# building_id           0.008761
# wind_speed            0.006071
# cloud_coverage        0.006024
# precip_depth_1_hr     0.000509
# wind_direction       -0.000078
# week                 -0.000737
# dew_temperature      -0.003330
# air_temperature      -0.004132
# sea_level_pressure   -0.004220
# Name: meter_reading, dtype: float64

# %%
building_id_site_id_meter_reading_weather
# Out:
#           building_id  meter            timestamp  meter_reading  site_id  \
# 0                   0      0  2016-01-01 00:00:00          0.000        0
# 1                   1      0  2016-01-01 00:00:00          0.000        0
# 2                   2      0  2016-01-01 00:00:00          0.000        0
# 3                   3      0  2016-01-01 00:00:00          0.000        0
# 4                   4      0  2016-01-01 00:00:00          0.000        0
# ...               ...    ...                  ...            ...      ...
# 20216095         1444      0  2016-12-31 23:00:00          8.750       15
# 20216096         1445      0  2016-12-31 23:00:00          4.825       15
# 20216097         1446      0  2016-12-31 23:00:00          0.000       15
# 20216098         1447      0  2016-12-31 23:00:00        159.575       15
# 20216099         1448      0  2016-12-31 23:00:00          2.850       15
#
#           air_temperature  cloud_coverage  dew_temperature  precip_depth_1_hr  \
# ...

# %%
from sklearn.impute import SimpleImputer as Imputer
imputer = Imputer(strategy="median")

tmp = building_id_site_id_meter_reading_weather.drop("timestamp", axis=1)
tmp = tmp.replace([np.inf, -np.inf], np.nan)

imputer.fit(tmp)
# Out:
# SimpleImputer(add_indicator=False, copy=True, fill_value=None,
#               missing_values=nan, strategy='median', verbose=0)

# %%
building_id_site_id_meter_reading_weather
# Out:
#           building_id  meter            timestamp  meter_reading  site_id  \
# 0                   0      0  2016-01-01 00:00:00          0.000        0
# 1                   1      0  2016-01-01 00:00:00          0.000        0
# 2                   2      0  2016-01-01 00:00:00          0.000        0
# 3                   3      0  2016-01-01 00:00:00          0.000        0
# 4                   4      0  2016-01-01 00:00:00          0.000        0
# ...               ...    ...                  ...            ...      ...
# 20216095         1444      0  2016-12-31 23:00:00          8.750       15
# 20216096         1445      0  2016-12-31 23:00:00          4.825       15
# 20216097         1446      0  2016-12-31 23:00:00          0.000       15
# 20216098         1447      0  2016-12-31 23:00:00        159.575       15
# 20216099         1448      0  2016-12-31 23:00:00          2.850       15
#
#           air_temperature  cloud_coverage  dew_temperature  precip_depth_1_hr  \
# ...

# %%
imputer.statistics_
# Out:
# array([8.9500e+02, 0.0000e+00, 7.8775e+01, 9.0000e+00, 1.6700e+01,
#        0.0000e+00, 8.9000e+00, 0.0000e+00, 1.0160e+03, 1.8000e+02,
#        3.1000e+00, 3.0000e+00, 7.2016e+04])

# %%
training = imputer.transform(tmp)

# %%
tmp.shape
# Out:
# (20216100, 13)

# %%
tmp
# Out:
#           building_id  meter  meter_reading  site_id  air_temperature  \
# 0                   0      0          0.000        0             25.0
# 1                   1      0          0.000        0             25.0
# 2                   2      0          0.000        0             25.0
# 3                   3      0          0.000        0             25.0
# 4                   4      0          0.000        0             25.0
# ...               ...    ...            ...      ...              ...
# 20216095         1444      0          8.750       15              1.7
# 20216096         1445      0          4.825       15              1.7
# 20216097         1446      0          0.000       15              1.7
# 20216098         1447      0        159.575       15              1.7
# 20216099         1448      0          2.850       15              1.7
#
#           cloud_coverage  dew_temperature  precip_depth_1_hr  \
# 0                    6.0             20.0                NaN
# ...

# %%
building_id_site_id_meter_reading_weather.isnull().any()
# Out:
# building_id           False
# meter                 False
# timestamp             False
# meter_reading         False
# site_id               False
# air_temperature        True
# cloud_coverage         True
# dew_temperature        True
# precip_depth_1_hr      True
# sea_level_pressure     True
# wind_direction         True
# wind_speed             True
# week                  False
# month                 False
# dtype: bool

# %%
import numpy as np
np.any(np.isfinite(tmp))
# Out:
# True

# %%
training
# Out:
# array([[0.00000e+00, 0.00000e+00, 0.00000e+00, ..., 0.00000e+00,
#         4.00000e+00, 1.20160e+04],
#        [1.00000e+00, 0.00000e+00, 0.00000e+00, ..., 0.00000e+00,
#         4.00000e+00, 1.20160e+04],
#        [2.00000e+00, 0.00000e+00, 0.00000e+00, ..., 0.00000e+00,
#         4.00000e+00, 1.20160e+04],
#        ...,
#        [1.44600e+03, 0.00000e+00, 0.00000e+00, ..., 8.80000e+00,
#         5.00000e+00, 1.22016e+05],
#        [1.44700e+03, 0.00000e+00, 1.59575e+02, ..., 8.80000e+00,
#         5.00000e+00, 1.22016e+05],
#        [1.44800e+03, 0.00000e+00, 2.85000e+00, ..., 8.80000e+00,
#         5.00000e+00, 1.22016e+05]])

# %%
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
# Out:
# 3.4209595221039574e-11

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-150-df3bf1194f2d> in <module>
#       3 # 決定木の作成
#       4 my_tree_one = tree.DecisionTreeClassifier()
# ----> 5 my_tree_one = my_tree_one.fit(training, label)
#       6 # 「test」の説明変数の値を取得
#       7 test_features = test[["meter", "wind_speed", "cloud_coverage", "month", "sea_level_pressure", "air_temperature", "dew_temperature"]].values
#
# ~/Documents/repo/ml/env/lib/python3.7/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     814             sample_weight=sample_weight,
#     815             check_input=check_input,
# --> 816             X_idx_sorted=X_idx_sorted)
#     817         return self
#     818
#
# ~/Documents/repo/ml/env/lib/python3.7/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     152
# ...

# %%
tmp = building_id_site_id_meter_reading_weather.drop("month", axis=1)

# %%
building_id_site_id_meter_reading_weather = tmp

# %%
building_id_site_id_meter_reading_weather
# Out:
#           building_id  meter            timestamp  meter_reading  site_id  \
# 0                   0      0  2016-01-01 00:00:00          0.000        0
# 1                   1      0  2016-01-01 00:00:00          0.000        0
# 2                   2      0  2016-01-01 00:00:00          0.000        0
# 3                   3      0  2016-01-01 00:00:00          0.000        0
# 4                   4      0  2016-01-01 00:00:00          0.000        0
# ...               ...    ...                  ...            ...      ...
# 20216095         1444      0  2016-12-31 23:00:00          8.750       15
# 20216096         1445      0  2016-12-31 23:00:00          4.825       15
# 20216097         1446      0  2016-12-31 23:00:00          0.000       15
# 20216098         1447      0  2016-12-31 23:00:00        159.575       15
# 20216099         1448      0  2016-12-31 23:00:00          2.850       15
#
#           air_temperature  cloud_coverage  dew_temperature  precip_depth_1_hr  \
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/Documents/repo/ml/env/lib/python3.7/site-packages/sklearn/impute/_base.py in _validate_input(self, X)
#     198             X = check_array(X, accept_sparse='csc', dtype=dtype,
# --> 199                             force_all_finite=force_all_finite, copy=self.copy)
#     200         except ValueError as ve:
#
# ~/Documents/repo/ml/env/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     495                 warnings.simplefilter('error', ComplexWarning)
# --> 496                 array = np.asarray(array, dtype=dtype, order=order)
#     497             except ComplexWarning:
#
# ...

# %%
train_prepared = train_tr

# %%
month_day = building_id_site_id_meter_reading_weather["timestamp"].str.replace('(.*)-(.*)-(.*) (.*)', r'\2\3', regex=True)
month_day_enc = month_day.replace('^0(.*)', r'\1', regex=True)
month_day_enc_int = month_day_enc.astype(int)
building_id_site_id_meter_reading_weather["month"] = month_day_enc_int

# %%
building_id_site_id_meter_reading_weather
# Out:
#           building_id  meter            timestamp  meter_reading  site_id  \
# 0                   0      0  2016-01-01 00:00:00          0.000        0
# 1                   1      0  2016-01-01 00:00:00          0.000        0
# 2                   2      0  2016-01-01 00:00:00          0.000        0
# 3                   3      0  2016-01-01 00:00:00          0.000        0
# 4                   4      0  2016-01-01 00:00:00          0.000        0
# ...               ...    ...                  ...            ...      ...
# 20216095         1444      0  2016-12-31 23:00:00          8.750       15
# 20216096         1445      0  2016-12-31 23:00:00          4.825       15
# 20216097         1446      0  2016-12-31 23:00:00          0.000       15
# 20216098         1447      0  2016-12-31 23:00:00        159.575       15
# 20216099         1448      0  2016-12-31 23:00:00          2.850       15
#
#           air_temperature  cloud_coverage  dew_temperature  precip_depth_1_hr  \
# ...

# %%
import numpy as np
class DataFrameImputer(TransformerMixin):

    def __init__(self):
        """Impute missing values.

        Columns of dtype object are imputed with the most frequent value 
        in column.

        Columns of other types are imputed with mean of column.

        """
    def fit(self, X, y=None):

        self.fill = pd.Series([X[c].value_counts().index[0]
            if X[c].dtype == np.dtype('O') else X[c].mean() for c in X],
            index=X.columns)

        return self

    def transform(self, X, y=None):
        return X.fillna(self.fill)

xt_num = DataFrameImputer().fit_transform(building_id_site_id_meter_reading_weather)

# %%
train_tr = xt_num

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer as Imputer
from sklearn.base import BaseEstimator, TransformerMixin

class DataFrameSelector(BaseEstimator, TransformerMixin):
    def __init__(self, attribute_names):
        self.attribute_names = attribute_names
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        return X[self.attribute_names].values

no_timestamp = train_tr.drop("timestamp", axis=1)
num_attribs = list(no_timestamp)

num_pipeline = Pipeline(
    [
        ('selector', DataFrameSelector(num_attribs)),
        ('std_scaler', StandardScaler()),
    ]
)

train_tr_ready = num_pipeline.fit_transform(train_tr)

# %%
train_tr_tmp = pd.DataFrame(train_tr_ready, columns=no_timestamp.columns)

# %%
train_tr_tmp["timestamp"] = train_tr["timestamp"]

# %%
train_prepared = train_tr_tmp

# %%
train_prepared
# Out:
#           building_id     meter  meter_reading   site_id  air_temperature  \
# 0           -1.872226 -0.711543      -0.013816 -1.567393         0.825197
# 1           -1.869883 -0.711543      -0.013816 -1.567393         0.825197
# 2           -1.867541 -0.711543      -0.013816 -1.567393         0.825197
# 3           -1.865198 -0.711543      -0.013816 -1.567393         0.825197
# 4           -1.862856 -0.711543      -0.013816 -1.567393         0.825197
# ...               ...       ...            ...       ...              ...
# 20216095     1.510194 -0.711543      -0.013759  1.374325        -1.308290
# 20216096     1.512537 -0.711543      -0.013785  1.374325        -1.308290
# 20216097     1.514879 -0.711543      -0.013816  1.374325        -1.308290
# 20216098     1.517221 -0.711543      -0.012775  1.374325        -1.308290
# 20216099     1.519564 -0.711543      -0.013798  1.374325        -1.308290
#
#           cloud_coverage  dew_temperature  precip_depth_1_hr  \
# ...

# %%
from sklearn.tree import DecisionTreeRegressor

target = train_prepared["meter_reading"]
features_one = train_prepared[["meter", "wind_speed", "sea_level_pressure", "air_temperature", "dew_temperature", "month"]].values

# 決定木の作成
my_tree_one = DecisionTreeRegressor()
my_tree_one = my_tree_one.fit(features_one, target)

# %%
# random forest

# %%
import lightgbm as lgb
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-77-5dacb4a27011> in <module>
# ----> 1 import lightgbm as lgb
#
# ModuleNotFoundError: No module named 'lightgbm'

# %%
weather_test = load_csv_data("weather_test.csv")

# %%
weather_test
# Out:
#         site_id            timestamp  air_temperature  cloud_coverage  \
# 0             0  2017-01-01 00:00:00             17.8             4.0
# 1             0  2017-01-01 01:00:00             17.8             2.0
# 2             0  2017-01-01 02:00:00             16.1             0.0
# 3             0  2017-01-01 03:00:00             17.2             0.0
# 4             0  2017-01-01 04:00:00             16.7             2.0
# ...         ...                  ...              ...             ...
# 277238       15  2018-12-31 19:00:00              3.3             NaN
# 277239       15  2018-12-31 20:00:00              2.8             NaN
# 277240       15  2018-12-31 21:00:00              2.8             NaN
# 277241       15  2018-12-31 22:00:00              2.8             NaN
# 277242       15  2018-12-31 23:00:00              3.3             NaN
#
#         dew_temperature  precip_depth_1_hr  sea_level_pressure  \
# ...

# %%
import pandas as pd
test_and_building_metadata = pd.merge(test, building_metadata,
                       how="left", on = "building_id")

# %%
test_and_building_metadata
# Out:
#             row_id  building_id  meter            timestamp  site_id  \
# 0                0            0      0  2017-01-01 00:00:00        0
# 1                1            1      0  2017-01-01 00:00:00        0
# 2                2            2      0  2017-01-01 00:00:00        0
# 3                3            3      0  2017-01-01 00:00:00        0
# 4                4            4      0  2017-01-01 00:00:00        0
# ...            ...          ...    ...                  ...      ...
# 41697595  41697595         1444      0  2018-05-09 07:00:00       15
# 41697596  41697596         1445      0  2018-05-09 07:00:00       15
# 41697597  41697597         1446      0  2018-05-09 07:00:00       15
# 41697598  41697598         1447      0  2018-05-09 07:00:00       15
# 41697599  41697599         1448      0  2018-05-09 07:00:00       15
#
#                             primary_use  square_feet  year_built  floor_count
# ...

# %%
test_tmp = pd.merge(test_and_building_metadata.iloc[:,[0,1,2,3,4]], 
                                                     weather_test, 
                                                     how="left", on=["site_id", "timestamp"])

# %%
test_tmp
# Out:
#             row_id  building_id  meter            timestamp  site_id  \
# 0                0            0      0  2017-01-01 00:00:00        0
# 1                1            1      0  2017-01-01 00:00:00        0
# 2                2            2      0  2017-01-01 00:00:00        0
# 3                3            3      0  2017-01-01 00:00:00        0
# 4                4            4      0  2017-01-01 00:00:00        0
# ...            ...          ...    ...                  ...      ...
# 41697595  41697595         1444      0  2018-05-09 07:00:00       15
# 41697596  41697596         1445      0  2018-05-09 07:00:00       15
# 41697597  41697597         1446      0  2018-05-09 07:00:00       15
# 41697598  41697598         1447      0  2018-05-09 07:00:00       15
# 41697599  41697599         1448      0  2018-05-09 07:00:00       15
#
#           air_temperature  cloud_coverage  dew_temperature  precip_depth_1_hr  \
# ...

# %%
month_day = test_tmp["timestamp"].str.replace('(.*)-(.*)-(.*) (.*)', r'\2\3', regex=True)
month_day_enc = month_day.replace('^0(.*)', r'\1', regex=True)
month_day_enc_int = month_day_enc.astype(int)
test_prepared["month"] = month_day_enc_int

# %%
test_pre = DataFrameImputer().fit_transform(test_prepared)

# %%
test_pre
# Out:
#             row_id  building_id  meter            timestamp  site_id  \
# 0                0            0      0  2017-01-01 00:00:00        0
# 1                1            1      0  2017-01-01 00:00:00        0
# 2                2            2      0  2017-01-01 00:00:00        0
# 3                3            3      0  2017-01-01 00:00:00        0
# 4                4            4      0  2017-01-01 00:00:00        0
# ...            ...          ...    ...                  ...      ...
# 41697595  41697595         1444      0  2018-05-09 07:00:00       15
# 41697596  41697596         1445      0  2018-05-09 07:00:00       15
# 41697597  41697597         1446      0  2018-05-09 07:00:00       15
# 41697598  41697598         1447      0  2018-05-09 07:00:00       15
# 41697599  41697599         1448      0  2018-05-09 07:00:00       15
#
#           air_temperature  cloud_coverage  dew_temperature  precip_depth_1_hr  \
# ...

# %%
# Out:
#             row_id  building_id  meter            timestamp  site_id  \
# 0                0            0      0  2017-01-01 00:00:00        0
# 1                1            1      0  2017-01-01 00:00:00        0
# 2                2            2      0  2017-01-01 00:00:00        0
# 3                3            3      0  2017-01-01 00:00:00        0
# 4                4            4      0  2017-01-01 00:00:00        0
# ...            ...          ...    ...                  ...      ...
# 41697595  41697595         1444      0  2018-05-09 07:00:00       15
# 41697596  41697596         1445      0  2018-05-09 07:00:00       15
# 41697597  41697597         1446      0  2018-05-09 07:00:00       15
# 41697598  41697598         1447      0  2018-05-09 07:00:00       15
# 41697599  41697599         1448      0  2018-05-09 07:00:00       15
#
#           air_temperature  cloud_coverage  dew_temperature  precip_depth_1_hr  \
# ...

# %%
# 「test」の説明変数の値を取得
test_features = test_pre[["meter", "wind_speed", "sea_level_pressure", "air_temperature", "dew_temperature", "month"]].values
# 「test」の説明変数を使って「my_tree_one」のモデルで予測
my_prediction = my_tree_one.predict(test_features)

# %%
my_prediction
# Out:
# array([-0.00098425, -0.00098425, -0.00098425, ..., -0.00098425,
#        -0.00098425, -0.00098425])

# %%
my_prediction.shape
# Out:
# (41697600,)

# %%
row_id = np.array(test_pre["row_id"]).astype(int)

# my_prediction(予測データ）とPassengerIdをデータフレームへ落とし込む
my_solution = pd.DataFrame(my_prediction, row_id, columns = ["meter_reading"])

# %%
tmp_my_solution = my_solution

tmp_my_solution.loc[tmp_my_solution['meter_reading'] < 0, 'meter_reading'] = 0

# %%
rounded_meter_reading = tmp_my_solution['meter_reading'].round(4)

# %%
rounded_meter_reading.iloc[20000000:20000100]
# Out:
# 20000000    0.1075
# 20000001    0.0000
# 20000002    0.0115
# 20000003    0.1075
# 20000004    0.1075
#              ...
# 20000095    0.0000
# 20000096    0.0115
# 20000097    0.1075
# 20000098    0.0000
# 20000099    0.0115
# Name: meter_reading, Length: 100, dtype: float64

# %%
# my_prediction(予測データ）とPassengerIdをデータフレームへ落とし込む
last_my_solution = pd.DataFrame(rounded_meter_reading, row_id, columns = ["meter_reading"])

# %%
# to csv
last_my_solution.to_csv("last_my_solution.csv.gz", index_label = ["row_id"], compression='gzip')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# KeyboardInterrupt:
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x226e2ddf0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x226e2ddf0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x226e2ddf0> returned a result with an error set
#
# ...
